# %% [markdown]
# <a href="https://colab.research.google.com/github/tejashanbhag5/car-dekho-data-analysis/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('/content/1776311302-P3-Car Market Trends Analysis with Car Dekho Data.csv')

data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
print(data.shape)
# Out:
# (301, 9)

# %%
print(data.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print(data.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(2)

# %%
data = data.drop_duplicates()

# %%
print(data.shape)
# Out:
# (299, 9)

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data["Fuel_Type"].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64

# %%
data["Seller_Type"].value_counts()
# Out:
# Seller_Type
# Dealer        193
# Individual    106
# Name: count, dtype: int64

# %%
data["Transmission"].value_counts()
# Out:
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %%
data["Owner"].value_counts()
# Out:
# Owner
# 0    288
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
data["Seller_Type"].value_counts()
# Out:
# Seller_Type
# Dealer        193
# Individual    106
# Name: count, dtype: int64

# %%
data["Transmission"].value_counts()
# Out:
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %%
data.corr(numeric_only=True)
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.234369      -0.053563   -0.525714 -0.181639
# Selling_Price  0.234369       1.000000       0.876378    0.028566 -0.087880
# Present_Price -0.053563       0.876378       1.000000    0.205253  0.009947
# Kms_Driven    -0.525714       0.028566       0.205253    1.000000  0.089367
# Owner         -0.181639      -0.087880       0.009947    0.089367  1.000000

# %%
data.corr(numeric_only=True)["Selling_Price"].sort_values(ascending=False)
# Out:
# Selling_Price    1.000000
# Present_Price    0.876378
# Year             0.234369
# Kms_Driven       0.028566
# Owner           -0.087880
# Name: Selling_Price, dtype: float64

# %%
data.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
data.describe(include="object")
# Out:
#        Car_Name Fuel_Type Seller_Type Transmission
# count       299       299         299          299
# unique       98         3           2            2
# top        city    Petrol      Dealer       Manual
# freq         26       239         193          260

# %%
data["Fuel_Type"].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64

# %%
data["Fuel_Type"].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64

# %%
data.groupby("Fuel_Type")["Selling_Price"].mean().sort_values(ascending=False)
# Out:
# Fuel_Type
# Diesel    10.102759
# Petrol     3.264184
# CNG        3.100000
# Name: Selling_Price, dtype: float64

# %%
data.groupby("Transmission")["Selling_Price"].mean().sort_values(ascending=False)
# Out:
# Transmission
# Automatic    9.071795
# Manual       3.917308
# Name: Selling_Price, dtype: float64

# %%
data.groupby(["Fuel_Type", "Seller_Type"])["Selling_Price"].mean()
# Out:
# Fuel_Type  Seller_Type
# CNG        Dealer          3.100000
# Diesel     Dealer          9.999298
#            Individual     16.000000
# Petrol     Dealer          5.252388
#            Individual      0.726857
# Name: Selling_Price, dtype: float64

# %%
data.groupby("Fuel_Type")["Selling_Price"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
data.groupby("Transmission")["Selling_Price"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Transmission'>

# %%
data.groupby("Seller_Type")["Selling_Price"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Seller_Type'>

# %%
data.groupby("Owner")["Selling_Price"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Owner'>

# %%
data.groupby("Owner")["Selling_Price"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Owner'>

# %%
data.groupby("Fuel_Type")["Selling_Price"].median().plot(kind="bar")
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
data.groupby("Seller_Type")["Selling_Price"].median().plot(kind="bar")
# Out:
# <Axes: xlabel='Seller_Type'>

# %%
data["Selling_Price"].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.groupby("Year")["Selling_Price"].mean().plot(kind="line", marker="o")
# Out:
# <Axes: xlabel='Year'>

# %%
data.plot(x="Present_Price", y="Selling_Price", kind="scatter")
# Out:
# <Axes: xlabel='Present_Price', ylabel='Selling_Price'>

# %%
data["Selling_Price"].plot(kind="box")
# Out:
# <Axes: >

# %%
data["Present_Price"].plot(kind="box")
# Out:
# <Axes: >
